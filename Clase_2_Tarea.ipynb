# %% [markdown]
# <a href="https://colab.research.google.com/github/Oks11111/TP_entrega_vpc2/blob/main/Clase_2_Tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio Práctico - Clase 2 VPC2 - 4co2021
#
# Generar una red convolucional con las siguientes caracteristicas:
#
# *   Conv1: cantidad de filtros=16, tramaño de filtro=3, stride=1, padding="same"
# *   Pool1: MaxPooling, tamaño de filtro=2, stride=2
# *   Conv2: cantidad de filtros=32, tramaño de filtro=3, stride=1, padding="same"
# *   Pool2: MaxPooling, tamaño de filtro=2, stride=2
# *   Conv3: cantidad de filtros=64, tramaño de filtro=3, stride=1, padding="same"
# *   Pool3: MaxPooling, tamaño de filtro=2, stride=2
# *   Conv4: cantidad de filtros=128, tramaño de filtro=3, stride=1, padding="same"
# *   Linear1: cantidad de neuronas=100
# *   Linear2: capa de salida
#
# Elegir la función de activación que crean mas conveniente.
#
# Ejercicios:
#
# 1.   Utilizando el dataset CIFAR10, provisto por PyTorch, entrenar la red sin aplicar data augmentation durante, al menos, 20 epocas. Se produce sobreentrenamiento?
# > Se produce sobreentrenamiento
# 2.   Utilizando el mismo dataset y aplicando las tecnicas de data augmentation que considere necesarias, entrenar nuevamente la red durante, al menos, 20 epocas sin que se produzca sobreentrenamiento hasta alcanzar un accuracy de 80% aproximadamente.
#
# 3.   A partir de los resultados obtenidos en los puntos anteriores: ¿Por qué cree que en el segundo caso el ritmo de mejora de la red es mas lento que en el primero?
# > Se debe al aumento de cantidad de datos.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.9.0-py3-none-any.whl (418 kB)
#      |████████████████████████████████| 418 kB 26.0 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.9.0

# %%
#!pip uninstall -y torchvision
#!pip uninstall -y torchvision # yes run the command again

# %%
#!pip install https://github.com/pytorch/vision/archive/master.zip

# %%
import torch
import torch.nn.functional as F
import torchvision
import torchsummary
import torchmetrics

# %%
train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)

print("### Descripción del conjunto de entrenamiento ###")
print(train_set)
print("### Dimensiones de un ejemplo del dataset ###")
print(np.shape(train_set[0][0]))
print("### Descripción del conjunto de evaluación ###")
print(test_set)

# Ploteo algunas imagenes del dataset y sus etiquetas
for i in range(9):
  image, label = train_set[i]
  plt.subplot(331 + i)
  plt.imshow(image, cmap=plt.get_cmap('gray'))
  print("Label de la imágen {}: {}".format(i, label))

plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ### Descripción del conjunto de entrenamiento ###
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
# ### Dimensiones de un ejemplo del dataset ###
# (32, 32, 3)
# ### Descripción del conjunto de evaluación ###
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
# Label de la imágen 0: 6
# Label de la imágen 1: 9
# Label de la imágen 2: 9
# Label de la imágen 3: 4
# Label de la imágen 4: 1
# Label de la imágen 5: 1
# Label de la imágen 6: 2
# Label de la imágen 7: 7
# Label de la imágen 8: 8

# %%
data_transforms = torchvision.transforms.Compose([
                    torchvision.transforms.Pad(padding=2),
                    torchvision.transforms.ToTensor(),
                    #torchvision.transforms.Normalize(mean=[0, 0, 0], std=[1, 1, 1])
                  ])

train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transforms)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=data_transforms)

valid_set_size = 5000

train_set, valid_set = torch.utils.data.random_split(train_set, [len(train_set) - valid_set_size, valid_set_size])

print("Tamaño del conjunto de entrenamiento: {}".format(len(train_set)))#
print("Tamaño del conjunto de validación: {}".format(len(valid_set)))

train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=len(valid_set), shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=len(test_set), shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Tamaño del conjunto de entrenamiento: 45000
# Tamaño del conjunto de validación: 5000

# %%
class LeNet5(torch.nn.Module):
    def __init__(self):
        super().__init__()
        #cantidad de filtros?
        #Cantidad de canales en la imagen de entrada: in_channels=1
        #Cantidad de canales producidos por la convolución: out_channels=6, 
        #tamaño de filtro (kernel) convolucional: kernel_size=5, 
        #stride: stride=1, 
        #tipo de padding: padding='same'
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding='same')
        self.pool1 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        self.conv2 = torch.nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding='same')
        self.pool2 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        self.conv3 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding='same')
        self.pool3 = torch.nn.AvgPool2d(kernel_size=2, stride=2)
        self.conv4 = torch.nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding='same')
        self.fc1 = torch.nn.Linear(in_features=2048, out_features=100)
        self.fc2 = torch.nn.Linear(in_features=100, out_features=10)
        #self.drop1 = torch.nn.Dropout(0.1)


    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = self.pool3(torch.relu(self.conv3(x)))
        x = torch.relu(self.conv4(x))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        
        
        return x

lenet5_model = LeNet5()

# %%
torchsummary.summary(lenet5_model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#          AvgPool2d-2           [-1, 16, 16, 16]               0
#             Conv2d-3           [-1, 32, 16, 16]           4,640
#          AvgPool2d-4             [-1, 32, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          18,496
#          AvgPool2d-6             [-1, 64, 4, 4]               0
#             Conv2d-7            [-1, 128, 4, 4]          73,856
#             Linear-8                  [-1, 100]         204,900
#             Linear-9                   [-1, 10]           1,010
# ================================================================
# Total params: 303,350
# Trainable params: 303,350
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.29
# Params size (MB): 1.16
# Estimated Total Size (MB): 1.46
# ----------------------------------------------------------------

# %%
lenet5_optimizer = torch.optim.SGD(lenet5_model.parameters(), lr=0.1)

lenet5_loss = torch.nn.CrossEntropyLoss()

lenet5_accuracy = torchmetrics.Accuracy()

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Epocas de entrenamiento
epochs = 20

# Agrego el grafico de la red a Tensorboard.
# [!] Debo pasarle una imagen por un bug en la funcion add_graph.
dataiter = iter(train_loader)
images, labels = dataiter.next()
writer.add_graph(lenet5_model, images)

# Defino listas para realizar graficas de los resultados
train_loss = []
train_acc = []
valid_loss = []
valid_acc = []

## Defino mi loop de entrenamiento

for epoch in range(epochs):

  epoch_train_loss = 0.0
  epoch_train_accuracy = 0.0

  for train_data, train_target in train_loader:

    # Seteo los gradientes en cero ya que, por defecto, PyTorch
    # los va acumulando
    lenet5_optimizer.zero_grad()

    # Realizo el forward pass de nuestro modelo
    output = lenet5_model(train_data)

    # Computo el error de la salida comparando contra las etiquetas
    loss = lenet5_loss(output, train_target)

    # Almaceno el error del batch para luego tener el error promedio de la epoca
    epoch_train_loss += loss.item()

    # Computo el nuevo set de gradientes a lo largo de toda la red
    loss.backward()

    # Realizo el paso de optimizacion actualizando los parametros de toda la red
    lenet5_optimizer.step()

    # Calculo el accuracy del batch
    accuracy = lenet5_accuracy(output, train_target)

    # Almaceno el accuracy del batch para luego tener el accuracy promedio de la epoca
    epoch_train_accuracy += accuracy.item()

  # Calculo la media de error y accuracy para la epoca de entrenamiento.
  # La longitud de train_loader es igual a la cantidad de batches dentro de una epoca.
  epoch_train_loss = epoch_train_loss / len(train_loader)
  epoch_train_accuracy = epoch_train_accuracy / len(train_loader)
  train_loss.append(epoch_train_loss)
  train_acc.append(epoch_train_accuracy)

  # Realizo el paso de validación computando error y accuracy, y
  # almacenando los valores para imprimirlos y graficarlos
  valid_data, valid_target = iter(valid_loader).next()
  output = lenet5_model(valid_data)
  epoch_valid_loss = lenet5_loss(output, valid_target).item()
  epoch_valid_accuracy = lenet5_accuracy(output, valid_target).item()
  valid_loss.append(epoch_valid_loss)
  valid_acc.append(epoch_valid_accuracy)

  print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
      epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))

  # Escribo los logs dentro de tensorboard
  writer.add_scalar("loss - train", epoch_train_loss, epoch)
  writer.add_scalar("loss - valid", epoch_valid_loss, epoch)
  writer.add_scalar("accuracy - train", epoch_train_accuracy, epoch)
  writer.add_scalar("accuracy - valid", epoch_valid_accuracy, epoch)
  writer.flush()
  
writer.close()
# Out:
# Epoch: 1/20 - Train loss 2.301720 - Train Accuracy 0.115760 - Valid Loss 2.299453 - Valid Accuracy 0.201000
# Epoch: 2/20 - Train loss 2.254652 - Train Accuracy 0.153029 - Valid Loss 2.099102 - Valid Accuracy 0.217200
# Epoch: 3/20 - Train loss 2.013841 - Train Accuracy 0.254731 - Valid Loss 1.965225 - Valid Accuracy 0.277800
# Epoch: 4/20 - Train loss 1.905138 - Train Accuracy 0.308702 - Valid Loss 1.855435 - Valid Accuracy 0.310000
# Epoch: 5/20 - Train loss 1.792231 - Train Accuracy 0.355499 - Valid Loss 1.767310 - Valid Accuracy 0.357200
# Epoch: 6/20 - Train loss 1.690133 - Train Accuracy 0.393346 - Valid Loss 1.684468 - Valid Accuracy 0.386800
# Epoch: 7/20 - Train loss 1.607724 - Train Accuracy 0.422974 - Valid Loss 1.613905 - Valid Accuracy 0.417200
# Epoch: 8/20 - Train loss 1.548465 - Train Accuracy 0.442497 - Valid Loss 1.533381 - Valid Accuracy 0.447600
# Epoch: 9/20 - Train loss 1.503704 - Train Accuracy 0.458733 - Valid Loss 1.541644 - Valid Accuracy 0.446600
# Epoch: 10/20 - Train loss 1.464133 - Train Accuracy 0.476235 - Valid Loss 1.522436 - Valid Accuracy 0.453200
# Epoch: 11/20 - Train loss 1.429888 - Train Accuracy 0.487496 - Valid Loss 1.483052 - Valid Accuracy 0.469600
# Epoch: 12/20 - Train loss 1.393616 - Train Accuracy 0.504064 - Valid Loss 1.444564 - Valid Accuracy 0.489400
# Epoch: 13/20 - Train loss 1.358874 - Train Accuracy 0.516236 - Valid Loss 1.377441 - Valid Accuracy 0.511200
# Epoch: 14/20 - Train loss 1.324928 - Train Accuracy 0.528340 - Valid Loss 1.365098 - Valid Accuracy 0.510800
# Epoch: 15/20 - Train loss 1.293351 - Train Accuracy 0.540134 - Valid Loss 1.404031 - Valid Accuracy 0.495200
# Epoch: 16/20 - Train loss 1.261168 - Train Accuracy 0.551595 - Valid Loss 1.362607 - Valid Accuracy 0.510000
# Epoch: 17/20 - Train loss 1.232464 - Train Accuracy 0.562989 - Valid Loss 1.301593 - Valid Accuracy 0.536800
# Epoch: 18/20 - Train loss 1.200230 - Train Accuracy 0.576670 - Valid Loss 1.265460 - Valid Accuracy 0.548800
# Epoch: 19/20 - Train loss 1.169075 - Train Accuracy 0.585310 - Valid Loss 1.296786 - Valid Accuracy 0.539000
# Epoch: 20/20 - Train loss 1.138767 - Train Accuracy 0.596326 - Valid Loss 1.389968 - Valid Accuracy 0.519800

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))
axs[0].plot(train_loss)
axs[0].plot(valid_loss) 
axs[0].title.set_text('Error de Entrenamiento vs Validación') 
axs[0].legend(['Train', 'Valid'])

axs[1].plot(train_acc) 
axs[1].plot(valid_acc) 
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación') 
axs[1].legend(['Train', 'Valid'])

# %%
# Realizo el paso de evaluación computando error y accuracy
test_data, test_target = iter(test_loader).next()
output = lenet5_model(test_data)
test_loss = lenet5_loss(output, test_target).item()
test_accuracy = lenet5_accuracy(output, test_target).item()

print("El modelo logro un error de {:.6f} y una accuracy de {:.6f}".format(test_loss, test_accuracy))
# Out:
# El modelo logro un error de 1.381475 y una accuracy de 0.526100

# %% [markdown]
# #### Vamos correr el mismo modelo con el dataset con data agumentation

# %%
data_transforms = torchvision.transforms.Compose([
                    torchvision.transforms.Pad(padding=2),
                    #torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
                    torchvision.transforms.RandomHorizontalFlip(0.5)
                    #,torchvision.transforms.functional.adjust_brightness(image,brightness_factor=2)
                    #,torchvision.transforms.GaussianBlur(kernel_size=3)
                    ,torchvision.transforms.ColorJitter(saturation=0.05, hue=0.05)
                    ,torchvision.transforms.RandomResizedCrop(size=(32, 32), scale=(0.5, 1))
                    , torchvision.transforms.ToTensor()])
                   




#transforms.RandomRotation(degrees=180)
#transforms.GaussianBlur(kernel_size=501)
#transforms.functional.adjust_brightness(image,brightness_factor=2)
#transforms.functional.adjust_contrast(image,contrast_factor=3.8)
#transforms.functional.adjust_hue(image,hue_factor=0.3)
#transforms.functional.adjust_saturation(image,saturation_factor=6)
#transforms.functional.adjust_sharpness(image,sharpness_factor=10)
#transforms.functional.equalize(image)
#

train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transforms)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=data_transforms)

valid_set_size = 10000

train_set, valid_set = torch.utils.data.random_split(train_set, [len(train_set) - valid_set_size, valid_set_size])

print("Tamaño del conjunto de entrenamiento: {}".format(len(train_set)))
print("Tamaño del conjunto de validación: {}".format(len(valid_set)))

train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=len(valid_set), shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=len(test_set), shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Tamaño del conjunto de entrenamiento: 40000
# Tamaño del conjunto de validación: 10000

# %%
# Epocas de entrenamiento
epochs = 100
# Agrego el grafico de la red a Tensorboard.
# [!] Debo pasarle una imagen por un bug en la funcion add_graph.
dataiter = iter(train_loader)
images, labels = dataiter.next()
writer.add_graph(lenet5_model, images)

# Defino listas para realizar graficas de los resultados
train_loss = []
train_acc = []
valid_loss = []
valid_acc = []

## Defino mi loop de entrenamiento

for epoch in range(epochs):

  epoch_train_loss = 0.0
  epoch_train_accuracy = 0.0

  for train_data, train_target in train_loader:

    # Seteo los gradientes en cero ya que, por defecto, PyTorch
    # los va acumulando
    lenet5_optimizer.zero_grad()

    # Realizo el forward pass de nuestro modelo
    output = lenet5_model(train_data)

    # Computo el error de la salida comparando contra las etiquetas
    loss = lenet5_loss(output, train_target)

    # Almaceno el error del batch para luego tener el error promedio de la epoca
    epoch_train_loss += loss.item()

    # Computo el nuevo set de gradientes a lo largo de toda la red
    loss.backward()

    # Realizo el paso de optimizacion actualizando los parametros de toda la red
    lenet5_optimizer.step()

    # Calculo el accuracy del batch
    accuracy = lenet5_accuracy(output, train_target)

    # Almaceno el accuracy del batch para luego tener el accuracy promedio de la epoca
    epoch_train_accuracy += accuracy.item()

  # Calculo la media de error y accuracy para la epoca de entrenamiento.
  # La longitud de train_loader es igual a la cantidad de batches dentro de una epoca.
  epoch_train_loss = epoch_train_loss / len(train_loader)
  epoch_train_accuracy = epoch_train_accuracy / len(train_loader)
  train_loss.append(epoch_train_loss)
  train_acc.append(epoch_train_accuracy)

  # Realizo el paso de validación computando error y accuracy, y
  # almacenando los valores para imprimirlos y graficarlos
  valid_data, valid_target = iter(valid_loader).next()
  output = lenet5_model(valid_data)
  epoch_valid_loss = lenet5_loss(output, valid_target).item()
  epoch_valid_accuracy = lenet5_accuracy(output, valid_target).item()
  valid_loss.append(epoch_valid_loss)
  valid_acc.append(epoch_valid_accuracy)

  print("Epoch: {}/{} - Train loss {:.6f} - Train Accuracy {:.6f} - Valid Loss {:.6f} - Valid Accuracy {:.6f}".format(
      epoch+1, epochs, epoch_train_loss, epoch_train_accuracy, epoch_valid_loss, epoch_valid_accuracy))

  # Escribo los logs dentro de tensorboard
  writer.add_scalar("loss - train", epoch_train_loss, epoch)
  writer.add_scalar("loss - valid", epoch_valid_loss, epoch)
  writer.add_scalar("accuracy - train", epoch_train_accuracy, epoch)
  writer.add_scalar("accuracy - valid", epoch_valid_accuracy, epoch)
  writer.flush()
  
writer.close()
# Out:
# Epoch: 1/100 - Train loss 1.843076 - Train Accuracy 0.332950 - Valid Loss 1.618214 - Valid Accuracy 0.410800
# Epoch: 2/100 - Train loss 1.593475 - Train Accuracy 0.425425 - Valid Loss 1.503412 - Valid Accuracy 0.454500
# Epoch: 3/100 - Train loss 1.504696 - Train Accuracy 0.455725 - Valid Loss 1.455311 - Valid Accuracy 0.472700
# Epoch: 4/100 - Train loss 1.431196 - Train Accuracy 0.486950 - Valid Loss 1.409608 - Valid Accuracy 0.492000
# Epoch: 5/100 - Train loss 1.364745 - Train Accuracy 0.508675 - Valid Loss 1.302827 - Valid Accuracy 0.531200
# Epoch: 6/100 - Train loss 1.313806 - Train Accuracy 0.526375 - Valid Loss 1.294780 - Valid Accuracy 0.537200
# Epoch: 7/100 - Train loss 1.267053 - Train Accuracy 0.546775 - Valid Loss 1.258303 - Valid Accuracy 0.551200
# Epoch: 8/100 - Train loss 1.227838 - Train Accuracy 0.560800 - Valid Loss 1.196238 - Valid Accuracy 0.574300
# Epoch: 9/100 - Train loss 1.186645 - Train Accuracy 0.577225 - Valid Loss 1.201896 - Valid Accuracy 0.575200
# Epoch: 10/100 - Train loss 1.151145 - Train Accuracy 0.589625 - Valid Loss 1.181850 - Valid Accuracy 0.577600
# Epoch: 11/100 - Train loss 1.117861 - Train Accuracy 0.600225 - Valid Loss 1.135141 - Valid Accuracy 0.596000
# Epoch: 12/100 - Train loss 1.091299 - Train Accuracy 0.611150 - Valid Loss 1.131379 - Valid Accuracy 0.597200
# Epoch: 13/100 - Train loss 1.055047 - Train Accuracy 0.623925 - Valid Loss 1.116960 - Valid Accuracy 0.604100
# Epoch: 14/100 - Train loss 1.030263 - Train Accuracy 0.633925 - Valid Loss 1.093113 - Valid Accuracy 0.614200
# Epoch: 15/100 - Train loss 1.004311 - Train Accuracy 0.647200 - Valid Loss 1.088105 - Valid Accuracy 0.618800
# Epoch: 16/100 - Train loss 0.981742 - Train Accuracy 0.652000 - Valid Loss 1.047992 - Valid Accuracy 0.633700
# Epoch: 17/100 - Train loss 0.964410 - Train Accuracy 0.659600 - Valid Loss 1.036226 - Valid Accuracy 0.639500
# Epoch: 18/100 - Train loss 0.938149 - Train Accuracy 0.670375 - Valid Loss 1.006179 - Valid Accuracy 0.649200
# Epoch: 19/100 - Train loss 0.922951 - Train Accuracy 0.673550 - Valid Loss 0.989575 - Valid Accuracy 0.653300
# Epoch: 20/100 - Train loss 0.902176 - Train Accuracy 0.679050 - Valid Loss 1.019824 - Valid Accuracy 0.643400
# Epoch: 21/100 - Train loss 0.881400 - Train Accuracy 0.692375 - Valid Loss 0.982656 - Valid Accuracy 0.654900
# Epoch: 22/100 - Train loss 0.873969 - Train Accuracy 0.691025 - Valid Loss 0.963364 - Valid Accuracy 0.662000
# Epoch: 23/100 - Train loss 0.851104 - Train Accuracy 0.698350 - Valid Loss 0.958063 - Valid Accuracy 0.669700
# Epoch: 24/100 - Train loss 0.845669 - Train Accuracy 0.704425 - Valid Loss 0.927481 - Valid Accuracy 0.676500
# Epoch: 25/100 - Train loss 0.833209 - Train Accuracy 0.704850 - Valid Loss 0.935978 - Valid Accuracy 0.674600
# Epoch: 26/100 - Train loss 0.817940 - Train Accuracy 0.712150 - Valid Loss 0.944389 - Valid Accuracy 0.678900
# Epoch: 27/100 - Train loss 0.812434 - Train Accuracy 0.713725 - Valid Loss 0.933991 - Valid Accuracy 0.677600
# Epoch: 28/100 - Train loss 0.794273 - Train Accuracy 0.719850 - Valid Loss 0.903619 - Valid Accuracy 0.685100
# Epoch: 29/100 - Train loss 0.790137 - Train Accuracy 0.723975 - Valid Loss 0.915640 - Valid Accuracy 0.683700
# Epoch: 30/100 - Train loss 0.777350 - Train Accuracy 0.726600 - Valid Loss 0.933631 - Valid Accuracy 0.679800
# Epoch: 31/100 - Train loss 0.765924 - Train Accuracy 0.731900 - Valid Loss 0.908912 - Valid Accuracy 0.685400
# Epoch: 32/100 - Train loss 0.755034 - Train Accuracy 0.737050 - Valid Loss 0.883380 - Valid Accuracy 0.695100
# Epoch: 33/100 - Train loss 0.751343 - Train Accuracy 0.736625 - Valid Loss 0.910887 - Valid Accuracy 0.683800
# Epoch: 34/100 - Train loss 0.744330 - Train Accuracy 0.738050 - Valid Loss 0.876465 - Valid Accuracy 0.698900
# Epoch: 35/100 - Train loss 0.740226 - Train Accuracy 0.738725 - Valid Loss 0.900217 - Valid Accuracy 0.695000
# Epoch: 36/100 - Train loss 0.722456 - Train Accuracy 0.745875 - Valid Loss 0.908602 - Valid Accuracy 0.694100
# Epoch: 37/100 - Train loss 0.717693 - Train Accuracy 0.746975 - Valid Loss 0.869932 - Valid Accuracy 0.697900
# Epoch: 38/100 - Train loss 0.722312 - Train Accuracy 0.748025 - Valid Loss 0.920027 - Valid Accuracy 0.688200
# Epoch: 39/100 - Train loss 0.705693 - Train Accuracy 0.749650 - Valid Loss 0.873086 - Valid Accuracy 0.700200
# Epoch: 40/100 - Train loss 0.688248 - Train Accuracy 0.760000 - Valid Loss 0.933607 - Valid Accuracy 0.693100
# Epoch: 41/100 - Train loss 0.693020 - Train Accuracy 0.759975 - Valid Loss 0.878038 - Valid Accuracy 0.706100
# Epoch: 42/100 - Train loss 0.686619 - Train Accuracy 0.761125 - Valid Loss 0.861376 - Valid Accuracy 0.707000
# Epoch: 43/100 - Train loss 0.683448 - Train Accuracy 0.760800 - Valid Loss 0.844491 - Valid Accuracy 0.710700
# Epoch: 44/100 - Train loss 0.673453 - Train Accuracy 0.761825 - Valid Loss 0.878537 - Valid Accuracy 0.705200
# Epoch: 45/100 - Train loss 0.673710 - Train Accuracy 0.763725 - Valid Loss 0.860134 - Valid Accuracy 0.712900
# Epoch: 46/100 - Train loss 0.666865 - Train Accuracy 0.765925 - Valid Loss 0.855519 - Valid Accuracy 0.713200
# Epoch: 47/100 - Train loss 0.667020 - Train Accuracy 0.764750 - Valid Loss 0.854081 - Valid Accuracy 0.713100
# Epoch: 48/100 - Train loss 0.653169 - Train Accuracy 0.770800 - Valid Loss 0.871298 - Valid Accuracy 0.706700
# Epoch: 49/100 - Train loss 0.651702 - Train Accuracy 0.770500 - Valid Loss 0.887669 - Valid Accuracy 0.709500
# Epoch: 50/100 - Train loss 0.648916 - Train Accuracy 0.772450 - Valid Loss 0.826913 - Valid Accuracy 0.723000
# Epoch: 51/100 - Train loss 0.644624 - Train Accuracy 0.774550 - Valid Loss 0.860716 - Valid Accuracy 0.712300
# Epoch: 52/100 - Train loss 0.639740 - Train Accuracy 0.775850 - Valid Loss 0.861753 - Valid Accuracy 0.711500
# Epoch: 53/100 - Train loss 0.640196 - Train Accuracy 0.776125 - Valid Loss 0.889562 - Valid Accuracy 0.704300
# Epoch: 54/100 - Train loss 0.633211 - Train Accuracy 0.777650 - Valid Loss 0.873229 - Valid Accuracy 0.706300
# Epoch: 55/100 - Train loss 0.637708 - Train Accuracy 0.775250 - Valid Loss 0.834832 - Valid Accuracy 0.722700
# Epoch: 56/100 - Train loss 0.632281 - Train Accuracy 0.780125 - Valid Loss 0.861131 - Valid Accuracy 0.718800
# Epoch: 57/100 - Train loss 0.624785 - Train Accuracy 0.780375 - Valid Loss 0.837161 - Valid Accuracy 0.719500
# Epoch: 58/100 - Train loss 0.624682 - Train Accuracy 0.778275 - Valid Loss 0.813864 - Valid Accuracy 0.727900
# Epoch: 59/100 - Train loss 0.616600 - Train Accuracy 0.783500 - Valid Loss 0.851504 - Valid Accuracy 0.708500
# Epoch: 60/100 - Train loss 0.619032 - Train Accuracy 0.784300 - Valid Loss 0.877044 - Valid Accuracy 0.717900
# Epoch: 61/100 - Train loss 0.615322 - Train Accuracy 0.784125 - Valid Loss 0.837185 - Valid Accuracy 0.720600
# Epoch: 62/100 - Train loss 0.608019 - Train Accuracy 0.785150 - Valid Loss 0.830280 - Valid Accuracy 0.727700
# Epoch: 63/100 - Train loss 0.602780 - Train Accuracy 0.789200 - Valid Loss 0.851557 - Valid Accuracy 0.722100
# Epoch: 64/100 - Train loss 0.604795 - Train Accuracy 0.788800 - Valid Loss 0.878585 - Valid Accuracy 0.711300
# Epoch: 65/100 - Train loss 0.603946 - Train Accuracy 0.790175 - Valid Loss 0.832874 - Valid Accuracy 0.727500
# Epoch: 66/100 - Train loss 0.598991 - Train Accuracy 0.792475 - Valid Loss 0.849041 - Valid Accuracy 0.721700
# Epoch: 67/100 - Train loss 0.601245 - Train Accuracy 0.788475 - Valid Loss 0.861328 - Valid Accuracy 0.721800
# Epoch: 68/100 - Train loss 0.593106 - Train Accuracy 0.792700 - Valid Loss 0.881287 - Valid Accuracy 0.717100
# Epoch: 69/100 - Train loss 0.588223 - Train Accuracy 0.796200 - Valid Loss 0.920170 - Valid Accuracy 0.697300
# Epoch: 70/100 - Train loss 0.584080 - Train Accuracy 0.795850 - Valid Loss 0.847323 - Valid Accuracy 0.720500
# Epoch: 71/100 - Train loss 0.584695 - Train Accuracy 0.797325 - Valid Loss 0.899091 - Valid Accuracy 0.708400
# Epoch: 72/100 - Train loss 0.589880 - Train Accuracy 0.795100 - Valid Loss 0.842249 - Valid Accuracy 0.729800
# Epoch: 73/100 - Train loss 0.582804 - Train Accuracy 0.795325 - Valid Loss 0.891808 - Valid Accuracy 0.710400
# Epoch: 74/100 - Train loss 0.587676 - Train Accuracy 0.796650 - Valid Loss 0.843498 - Valid Accuracy 0.724800
# Epoch: 75/100 - Train loss 0.579091 - Train Accuracy 0.798450 - Valid Loss 0.828713 - Valid Accuracy 0.727900
# Epoch: 76/100 - Train loss 0.577272 - Train Accuracy 0.797250 - Valid Loss 0.851236 - Valid Accuracy 0.723400
# Epoch: 77/100 - Train loss 0.576307 - Train Accuracy 0.800125 - Valid Loss 0.857979 - Valid Accuracy 0.725000
# Epoch: 78/100 - Train loss 0.573945 - Train Accuracy 0.799375 - Valid Loss 0.875916 - Valid Accuracy 0.720200
# Epoch: 79/100 - Train loss 0.570466 - Train Accuracy 0.802650 - Valid Loss 0.826058 - Valid Accuracy 0.727800
# Epoch: 80/100 - Train loss 0.565993 - Train Accuracy 0.801400 - Valid Loss 0.842714 - Valid Accuracy 0.726400
# Epoch: 81/100 - Train loss 0.565502 - Train Accuracy 0.803725 - Valid Loss 0.868212 - Valid Accuracy 0.716400
# Epoch: 82/100 - Train loss 0.569040 - Train Accuracy 0.801350 - Valid Loss 0.829685 - Valid Accuracy 0.728700
# Epoch: 83/100 - Train loss 0.566466 - Train Accuracy 0.805025 - Valid Loss 0.853409 - Valid Accuracy 0.719300
# Epoch: 84/100 - Train loss 0.569217 - Train Accuracy 0.801250 - Valid Loss 0.825302 - Valid Accuracy 0.734000
# Epoch: 85/100 - Train loss 0.563481 - Train Accuracy 0.804950 - Valid Loss 0.874519 - Valid Accuracy 0.712700
# Epoch: 86/100 - Train loss 0.556989 - Train Accuracy 0.806100 - Valid Loss 0.828659 - Valid Accuracy 0.734400
# Epoch: 87/100 - Train loss 0.553054 - Train Accuracy 0.806775 - Valid Loss 0.827984 - Valid Accuracy 0.731000
# Epoch: 88/100 - Train loss 0.554953 - Train Accuracy 0.807750 - Valid Loss 0.845726 - Valid Accuracy 0.726200
# Epoch: 89/100 - Train loss 0.556908 - Train Accuracy 0.803800 - Valid Loss 0.844938 - Valid Accuracy 0.730400
# Epoch: 90/100 - Train loss 0.550172 - Train Accuracy 0.808350 - Valid Loss 0.861336 - Valid Accuracy 0.729100
# Epoch: 91/100 - Train loss 0.548086 - Train Accuracy 0.807975 - Valid Loss 0.875258 - Valid Accuracy 0.718700
# Epoch: 92/100 - Train loss 0.539038 - Train Accuracy 0.811025 - Valid Loss 0.838598 - Valid Accuracy 0.733200
# Epoch: 93/100 - Train loss 0.549695 - Train Accuracy 0.809400 - Valid Loss 0.846543 - Valid Accuracy 0.723100
# Epoch: 94/100 - Train loss 0.543803 - Train Accuracy 0.809575 - Valid Loss 0.810978 - Valid Accuracy 0.737100
# Epoch: 95/100 - Train loss 0.546941 - Train Accuracy 0.809175 - Valid Loss 0.863855 - Valid Accuracy 0.727400
# Epoch: 96/100 - Train loss 0.540316 - Train Accuracy 0.810525 - Valid Loss 0.827823 - Valid Accuracy 0.727600
# Epoch: 97/100 - Train loss 0.543036 - Train Accuracy 0.811125 - Valid Loss 0.895343 - Valid Accuracy 0.726700
# Epoch: 98/100 - Train loss 0.542060 - Train Accuracy 0.811325 - Valid Loss 0.871601 - Valid Accuracy 0.728900
# Epoch: 99/100 - Train loss 0.542880 - Train Accuracy 0.812600 - Valid Loss 0.850592 - Valid Accuracy 0.728500
# Epoch: 100/100 - Train loss 0.530732 - Train Accuracy 0.816300 - Valid Loss 0.852067 - Valid Accuracy 0.733600

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))
axs[0].plot(train_loss)
axs[0].plot(valid_loss) 
axs[0].title.set_text('Error de Entrenamiento vs Validación') 
axs[0].legend(['Train', 'Valid'])

axs[1].plot(train_acc) 
axs[1].plot(valid_acc) 
axs[1].title.set_text('Accuracy de Entrenamiento vs Validación') 
axs[1].legend(['Train', 'Valid'])
